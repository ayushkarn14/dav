# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cols=['Sepal_length','Sepal_width','Petal_length','Petal_width','class']
df=pd.read_csv('iris.csv',names=cols)
df
# Out:
#      Sepal_length  Sepal_width  Petal_length  Petal_width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
freq=df['class'].value_counts()
print(freq)
plt.bar(freq.index,freq.values)
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64
# <BarContainer object of 3 artists>

# %%
plt.scatter(df['Petal_width'],df['Sepal_width'])
plt.xlabel("Petal Width")
plt.ylabel("Sepal Width")
plt.title("Petal width vs Sepal Width scatter plot")
# Out:
# Text(0.5, 1.0, 'Petal width vs Sepal Width scatter plot')

# %%
plt.hist(df['Petal_length'],bins=40)
plt.xlabel("Petal length")
plt.ylabel("Frequency")
plt.show()

# %%
sns.pairplot(df,hue='class',palette='cool')
# Out:
# /home/ayush/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /home/ayush/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /home/ayush/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /home/ayush/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /home/ayush/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# ...

# %%
sns.pairplot(df)
